# %%
from chatterbot import ChatBot
from chatterbot.trainers import ListTrainer
import os 
import random

bot = ChatBot('Bot')
bot.set_trainer(ListTrainer)

for files in os.listdir('Chatterbot_data/english/'):
    data = open('Chatterbot_data/english/' + files,'r').readlines()
    bot.train(data)
    
while True:
    message = input('You')
    if message.strip() != 'Bye':
        reply = bot.random.choice(get_response(message))
        print('ChatBot : ',reply)
    if message.strip() == 'Bye':
        print('ChatBot : Bye')
        break
# Out:
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [####################] 100%
# List Trainer: [#######             ] 33%
